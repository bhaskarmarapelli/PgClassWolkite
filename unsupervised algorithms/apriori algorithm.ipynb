# %%
import numpy as nm  
import matplotlib.pyplot as mtp  
import pandas as pd

# %%
import os
os.chdir("C:\\Users\\bhaskar\\python practice\\datasets")
#Importing the dataset  
dataset = pd.read_csv('Market_Basket_Optimisation.csv')

# %%
dataset
# Out:
#                  shrimp            almonds            avocado  \
# 0               burgers          meatballs               eggs
# 1               chutney                NaN                NaN
# 2                turkey            avocado                NaN
# 3         mineral water               milk         energy bar
# 4        low fat yogurt                NaN                NaN
# 5     whole wheat pasta       french fries                NaN
# 6                  soup        light cream            shallot
# 7     frozen vegetables          spaghetti          green tea
# 8          french fries                NaN                NaN
# 9                  eggs           pet food                NaN
# 10              cookies                NaN                NaN
# 11               turkey            burgers      mineral water
# 12            spaghetti          champagne            cookies
# 13        mineral water             salmon                NaN
# ...

# %%
dataset.shape
# Out:
# (7500, 20)

# %%
transactions=[]  
for i in range(0, 30):  
    transactions.append([str(dataset.values[i,j])  for j in range(0,10)])

# %%
pip install apyori
# Out:
# ...
#   Stored in directory: C:\Users\bhaskar\AppData\Local\pip\Cache\wheels\5d\92\bb\474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from apyori import apriori  
rules= apriori(records, min_support=0.003, min_confidence = 0.2, min_lift=3, min_length=2)

# %%
results= list(rules)  
results
# Out:
# [RelationRecord(items=frozenset({'frankfurter', '10'}), support=0.0061902082160945416, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'frankfurter'}), confidence=0.21568627450980393, lift=3.141594342655095)]),
#  RelationRecord(items=frozenset({'10', 'fruit/vegetable juice'}), support=0.009003939223410242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'fruit/vegetable juice'}), confidence=0.3137254901960784, lift=4.321629426964584)]),
#  RelationRecord(items=frozenset({'10', 'root vegetables'}), support=0.012380416432189083, ordered_statistics=[OrderedStatistic(items_base=frozenset({'10'}), items_add=frozenset({'root vegetables'}), confidence=0.43137254901960786, lift=3.9109643857543017)]),
# ...

# %%
for item in results:  
    pair = item[0]   
    items = [x for x in pair]  
    print("Rule: " + items[0] + " -> " + items[1])  
  
    print("Support: " + str(item[1]))  
    print("Confidence: " + str(item[2][0][2]))  
    print("Lift: " + str(item[2][0][3]))  
    print("=====================================")
# Out:
# Rule: frankfurter -> 10
# Support: 0.0061902082160945416
# Confidence: 0.21568627450980393
# Lift: 3.141594342655095
# ...
# Rule: 10 -> fruit/vegetable juice
# Support: 0.009003939223410242
# Confidence: 0.3137254901960784
# Lift: 4.321629426964584
# ...
# Rule: 10 -> root vegetables
# Support: 0.012380416432189083
# Confidence: 0.43137254901960786
# Lift: 3.9109643857543017
# ...
# Rule: beef -> 11
# Support: 0.004501969611705121
# Confidence: 0.22222222222222224
# Lift: 3.760846560846561
# ...
# Rule: butter -> 11
# Support: 0.004501969611705121
# Confidence: 0.22222222222222224
# Lift: 3.8338727076591157
# ...
# Rule: coffee -> 11
# Support: 0.004501969611705121
# Confidence: 0.22222222222222224
# Lift: 3.0144189991518235
# ...
# Rule: domestic eggs -> 11
# Support: 0.005627462014631401
# Confidence: 0.2777777777777778
# Lift: 4.368239921337267
# ...
# Rule: margarine -> 11
# Support: 0.005064715813168261
# Confidence: 0.25
# Lift: 4.002252252252252
# ...
# Rule: sausage -> 11
# Support: 0.0061902082160945416
# ...

# %% [markdown]
# # From the above output, we can analyze each rule. some rule, which is baking powder → sugar, states that the baking powder and sugar are bought frequently by most of the customers. The support for this rule is 0.0056, and the confidence is 30%. Hence, if a customer buys lbaking powde, it is 30% chances that he also buys  sugar, and it is .0056 times appeared in the transactions. We can check all these things in other rules also.
